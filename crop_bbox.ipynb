# %%
import os
import json
import cv2
import numpy as np
import pandas as pd


def crop_and_save_polygons(json_folder, image_root, save_folder, ann_output_csv):
    os.makedirs(save_folder, exist_ok=True)
    records = []
    for file in os.listdir(json_folder):
        if not file.endswith(".json"):
            continue
        json_path = os.path.join(json_folder, file)
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        # Tìm tên ảnh đúng (xử lý nếu đường dẫn lạ)
        imgname = os.path.basename(data["imagePath"]).replace("..\\images\\", "")
        image_path = os.path.join(image_root, imgname)
        if not os.path.exists(image_path):
            print("Không tìm thấy ảnh:", image_path)
            continue
        image = cv2.imread(image_path)
        if image is None:
            print("Lỗi đọc ảnh:", image_path)
            continue
        base_name = os.path.splitext(imgname)[0]
        for idx, shape in enumerate(data["shapes"]):
            if shape.get("shape_type", "polygon") != "polygon":
                continue
            label = shape.get("label", "")
            desc = shape.get("description", "")
            points = np.array(shape["points"], dtype=np.float32)
            points_int = np.round(points).astype(np.int32).reshape((-1, 1, 2))
            mask = np.zeros(image.shape[:2], dtype=np.uint8)
            cv2.fillPoly(mask, [points_int], 255)
            x, y, w, h = cv2.boundingRect(points_int)
            crop_img = image[y : y + h, x : x + w].copy()
            crop_mask = mask[y : y + h, x : x + w]
            bg = np.ones_like(crop_img, dtype=np.uint8) * 255  # background trắng
            crop_img_masked = np.where(crop_mask[..., None] == 255, crop_img, bg)
            crop_fname = f"{base_name}_crop_{idx}.jpg"
            out_path = os.path.join(save_folder, crop_fname)
            cv2.imwrite(out_path, crop_img_masked)
            # Lưu annotation cho OCR
            records.append(
                {"filename": crop_fname, "label": label, "description_gt": desc}
            )
    # Lưu bảng annotation
    pd.DataFrame(records).to_csv(ann_output_csv, index=False)
    print("Đã crop xong:", len(records), "vùng, bảng annotation:", ann_output_csv)
    return records


# ==== Chạy thử nghiệm ====
# Thay đổi đúng đường dẫn
json_folder = "./dataset_original/labels"
image_root = "./dataset_original/images"
save_folder = "./dataset_original/crops"
ann_output_csv = os.path.join(save_folder, "crops_gt.csv")

crop_and_save_polygons(json_folder, image_root, save_folder, ann_output_csv)
# Out:
# Đã crop xong: 2284 vùng, bảng annotation: ./dataset_original/crops\crops_gt.csv
# [{'filename': '001_heo-cao-boi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'HEO CAO BỒI'},
#  {'filename': '001_heo-cao-boi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'THỊT VIÊN 3 PHÚT'},
#  {'filename': '001_heo-cao-boi_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '150824'},
#  {'filename': '001_heo-cao-boi_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '150825'},
#  {'filename': '001_heo-cao-boi_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '001_heo-cao-boi_F_crop_5.jpg',
#   'label': 'weight',
#   'description_gt': '100 g'},
#  {'filename': '002_mi-ly-modern_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ACECOOK'},
#  {'filename': '002_mi-ly-modern_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'MÌ LY MODERN'},
#  {'filename': '003_banh-crepe-sua-tuoi_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'SweetHome Bakery'},
#  {'filename': '003_banh-crepe-sua-tuoi_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH CREPE SỮA TƯƠI'},
#  {'filename': '003_banh-crepe-sua-tuoi_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '80g'},
#  {'filename': '003_banh-crepe-sua-tuoi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '05/11/2024'},
#  {'filename': '003_banh-crepe-sua-tuoi_B_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '24h 11/11/2024'},
#  {'filename': '003_banh-crepe-sua-tuoi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'SweetHome Bakery'},
#  {'filename': '003_banh-crepe-sua-tuoi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Crepe Sữa Tươi'},
#  {'filename': '003_che-buoi_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Chè Bưởi'},
#  {'filename': '003_che-buoi_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'TNT Foods'},
#  {'filename': '003_che-buoi_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '140 g'},
#  {'filename': '003_che-buoi_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '06/11/2024'},
#  {'filename': '003_che-buoi_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '10/11/2024'},
#  {'filename': '004_cal-cheese_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'MAYORA'},
#  {'filename': '004_cal-cheese_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '48g'},
#  {'filename': '004_cal-cheese_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '48g'},
#  {'filename': '004_cal-cheese_F_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'Thực Phẩm Bổ Sung Bánh Xốp Kem Phô Mai Cal Cheese'},
#  {'filename': '004_cal-cheese_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '19 08 2024'},
#  {'filename': '004_cal-cheese_F_crop_5.jpg',
#   'label': 'date',
#   'description_gt': '10 06 2025'},
#  {'filename': '005_nabati_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'nabati WAFER'},
#  {'filename': '006_nabati_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '07/10/2025'},
#  {'filename': '006_nabati_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '07/10/2024'},
#  {'filename': '007_snack-nhan-dau-phong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'SNACK NHÂN ĐẬU PHỘNG'},
#  {'filename': '007_snack-nhan-dau-phong_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Oishi'},
#  {'filename': '008_sting-vang_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'STING NƯỚC TĂNG LỰC'},
#  {'filename': '009_sting-vang_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'NƯỚC TĂNG LỰC STING'},
#  {'filename': '009_sting-vang_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '320 ml'},
#  {'filename': '010_sting_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'STING NƯỚC TĂNG LỰC'},
#  {'filename': '011_sting_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'NƯỚC TĂNG LỰC STING HƯƠNG DÂU TÂY ĐỎ'},
#  {'filename': '011_sting_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '320 ml'},
#  {'filename': '012_banh-hoa-cuc_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': "Fe'sta"},
#  {'filename': '012_banh-hoa-cuc_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Hoa cúc ngàn lớp'},
#  {'filename': '013_snack-vi-suon-nuong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': "Lay's"},
#  {'filename': '013_snack-vi-suon-nuong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Vị Sườn Nướng BBQ Brazil'},
#  {'filename': '014_mentos-keo-ngam-khong-duong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'KẸO NGẬM KHÔNG ĐƯỜNG'},
#  {'filename': '014_mentos-keo-ngam-khong-duong_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'mentos'},
#  {'filename': '015_mentos-keo-ngam-khong-duong_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'KẸO NGẬM KHÔNG ĐƯỜNG'},
#  {'filename': '015_mentos-keo-ngam-khong-duong_B_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'mentos'},
#  {'filename': '015_mentos-keo-ngam-khong-duong_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '35 g'},
#  {'filename': '018_himalaya-salt_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'HIMALAYA SALT'},
#  {'filename': '018_himalaya-salt_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'HIMALAYA Sports'},
#  {'filename': '019_himalaya-salt_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'HIMALAYA SALT'},
#  {'filename': '019_himalaya-salt_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'KẸO MUỐI HIMALAYA BẠC HÀ VỊ CHANH'},
#  {'filename': '019_himalaya-salt_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '15g'},
#  {'filename': '019_himalaya-salt_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '10/09/2024'},
#  {'filename': '019_himalaya-salt_B_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '09/09/2026'},
#  {'filename': '019_himalaya-salt_B_crop_5.jpg',
#   'label': 'weight',
#   'description_gt': '15g'},
#  {'filename': '020_marshmallows_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Teddy MARSHMALLOWS'},
#  {'filename': '021_marshmallows_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Teddy Marshallows'},
#  {'filename': '021_marshmallows_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '70g'},
#  {'filename': '022_marshmallows_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '02/07/2024'},
#  {'filename': '022_marshmallows_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '01/10/2025'},
#  {'filename': '022_marshmallows_B_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'Kẹo dẻo tổng hợp Marshmallows hình Teddy'},
#  {'filename': '023_lap-xuong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'LẠP XƯỞNG'},
#  {'filename': '023_lap-xuong_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Greenfeed'},
#  {'filename': '024_lap-xuong_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '25/11/2024'},
#  {'filename': '024_lap-xuong_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '25/06/2025'},
#  {'filename': '025_rong-bien_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Green World'},
#  {'filename': '025_rong-bien_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Rong Biển'},
#  {'filename': '025_rong-bien_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '20 g'},
#  {'filename': '026_vinamilk-sua-dinh-duong-socola_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Vinamilk'},
#  {'filename': '026_vinamilk-sua-dinh-duong-socola_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'SỮA DINH DƯỠNG '},
#  {'filename': '026_vinamilk-sua-dinh-duong-socola_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '220 ml'},
#  {'filename': '027_vinamilk-sua-dinh-duong-socola_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '250425'},
#  {'filename': '027_vinamilk-sua-dinh-duong-socola_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '06 tháng trước HSD.'},
#  {'filename': '028_dau-an-happi-koki_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'happi Koki'},
#  {'filename': '028_dau-an-happi-koki_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'DẦU ĂN CAO CẤP'},
#  {'filename': '028_dau-an-happi-koki_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '029_dau-an-light_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Neptune Light'},
#  {'filename': '030_dau-an-light_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'DẦU ĂN THƯỢNG HẠNG'},
#  {'filename': '030_dau-an-light_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '031_dau-an-cai-lan_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Cái Lân'},
#  {'filename': '031_dau-an-cai-lan_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'DẦU THỰC VẬT HẢO HẠNG'},
#  {'filename': '032_dau-an-cai-lan_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Cái Lân'},
#  {'filename': '032_dau-an-cai-lan_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '032_dau-an-cai-lan_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '24 tháng trước hạn sử dụng (HSD).'},
#  {'filename': '033_dau-an-bep-hong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Bếp Hồng'},
#  {'filename': '033_dau-an-bep-hong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Dầu thực vật tinh luyện'},
#  {'filename': '033_dau-an-bep-hong_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '1 Lít'},
#  {'filename': '034_dau-an-orchid_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'orchid'},
#  {'filename': '034_dau-an-orchid_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Dầu Thực Vật Tinh Luyện'},
#  {'filename': '035_dau-an-orchid_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '24 tháng trước hạn sử dụng (HSD)'},
#  {'filename': '035_dau-an-orchid_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '036_dau-an-good-meall_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Good Meall'},
#  {'filename': '036_dau-an-good-meall_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Dầu thực vật cao cấp'},
#  {'filename': '036_dau-an-good-meall_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '037_dau-dau-nanh-simply_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Simply'},
#  {'filename': '037_dau-dau-nanh-simply_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'DẦU ĐẬU NÀNH'},
#  {'filename': '038_dau-dau-nanh-simply_B_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '038_dau-dau-nanh-simply_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Dầu Đậu Nành Simply'},
#  {'filename': '039_dau-dau-nanh-truong-an_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '101224'},
#  {'filename': '039_dau-dau-nanh-truong-an_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '101226'},
#  {'filename': '039_dau-dau-nanh-truong-an_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'Tường An'},
#  {'filename': '039_dau-dau-nanh-truong-an_F_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'DẦU ĐẬU NÀNH'},
#  {'filename': '040_dau-dau-nanh-truong-an_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Tường An'},
#  {'filename': '040_dau-dau-nanh-truong-an_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'DÂU ĐẬU NÀNH'},
#  {'filename': '040_dau-dau-nanh-truong-an_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '1 lít'},
#  {'filename': '041_bo-dau-phong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'GOLDEN FARM'},
#  {'filename': '041_bo-dau-phong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BƠ ĐẬU PHỘNG'},
#  {'filename': '041_bo-dau-phong_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '170 g'},
#  {'filename': '042_bo-dau-phong_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '02.01.26'},
#  {'filename': '042_bo-dau-phong_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '02.10.24'},
#  {'filename': '043_bo-thuc-vat_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Tường An'},
#  {'filename': '043_bo-thuc-vat_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BƠ THỰC VẬT'},
#  {'filename': '044_bo-thuc-vat_B_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '200g'},
#  {'filename': '045_nui-trung_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'nui trứng cao cấp'},
#  {'filename': '045_nui-trung_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'erici'},
#  {'filename': '046_nui-trung_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '18/11/2024'},
#  {'filename': '046_nui-trung_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '18/11/2025'},
#  {'filename': '046_nui-trung_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '400 g'},
#  {'filename': '047_nui-bon-mua_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'NUI BỐN MÙA'},
#  {'filename': '047_nui-bon-mua_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '050_nui-ong-dai_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Bà Bảy'},
#  {'filename': '050_nui-ong-dai_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Nui ống dài'},
#  {'filename': '050_nui-ong-dai_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '500g'},
#  {'filename': '051_mi-trung-cao-cap_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Mì Trứng Cao Cấp'},
#  {'filename': '051_mi-trung-cao-cap_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': 'MEIZAN'},
#  {'filename': '051_nui-gao-lotus_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Lotus'},
#  {'filename': '051_nui-gao-lotus_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'NUI GẠO NGUYÊN CHẤT'},
#  {'filename': '052_mi-trung-cao-cap_L_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '18125'},
#  {'filename': '052_nui-chu-c_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Bà Bảy'},
#  {'filename': '052_nui-chu-c_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Nui Chữ C'},
#  {'filename': '052_nui-chu-c_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '053_tuong-ot-knorr_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr'},
#  {'filename': '053_tuong-ot-knorr_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr SINCE 1838'},
#  {'filename': '053_tuong-ot-knorr_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'TƯƠNG ỚT TRÒN 5 VỊ!'},
#  {'filename': '054_tuong-ot-knorr_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr'},
#  {'filename': '054_tuong-ot-knorr_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '11.11.24'},
#  {'filename': '054_tuong-ot-knorr_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '11.10.23'},
#  {'filename': '054_tuong-ot-knorr_B_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'TƯƠNG ỚT TRÒN 5 VỊ!'},
#  {'filename': '054_tuong-ot-knorr_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '220g'},
#  {'filename': '055_tuong-ca-nam-duong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Namduong'},
#  {'filename': '055_tuong-ca-nam-duong_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '081125'},
#  {'filename': '055_tuong-ca-nam-duong_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'NamDương'},
#  {'filename': '055_tuong-ca-nam-duong_F_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'Tương Cà'},
#  {'filename': '056_tuong-ca-nam-duong_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Namduong'},
#  {'filename': '056_tuong-ca-nam-duong_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '255 g'},
#  {'filename': '057_tuong-ot-xanh_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Ông Chà Và'},
#  {'filename': '057_tuong-ot-xanh_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Ớt Xanh Tương'},
#  {'filename': '057_tuong-ot-xanh_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '220 g'},
#  {'filename': '058_tuong-ot-xanh_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Ông Chà Và'},
#  {'filename': '058_tuong-ot-xanh_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '220 g'},
#  {'filename': '058_tuong-ot-xanh_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '12 tháng trước HSD'},
#  {'filename': '059_tuong-ot-ong-cha-va_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Ông Chả Và'},
#  {'filename': '059_tuong-ot-ong-cha-va_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Tương ớt'},
#  {'filename': '060_tuong-ot-ong-cha-va_B_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '280 g'},
#  {'filename': '060_tuong-ot-ong-cha-va_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '12 tháng trước HSD'},
#  {'filename': '061_tuong-ot-sieu-cay_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'TAI LOC FOODS'},
#  {'filename': '061_tuong-ot-sieu-cay_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'TƯƠNG ỚT SIÊU CAY'},
#  {'filename': '061_tuong-ot-sieu-cay_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '530g'},
#  {'filename': '062_tuong-ot-sieu-cay_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '03/12/24'},
#  {'filename': '062_tuong-ot-sieu-cay_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '03/12/25'},
#  {'filename': '062_tuong-ot-sieu-cay_B_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'TAI LOC FOODS'},
#  {'filename': '063_tuong-ot-sieu-cay_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'TAILOCFOODS'},
#  {'filename': '063_tuong-ot-sieu-cay_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'TƯƠNG ỚT SIÊU CAY'},
#  {'filename': '063_tuong-ot-sieu-cay_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '530 g'},
#  {'filename': '064_tuong-ot-dellycook_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Dellycook'},
#  {'filename': '064_tuong-ot-dellycook_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Tương Ớt CHILI SAUCE '},
#  {'filename': '065_tuong-ot-dellycook_B_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '270 g'},
#  {'filename': '066_tuong-ot-dellycook_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '20.03.2024'},
#  {'filename': '066_tuong-ot-dellycook_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '20.03.2025'},
#  {'filename': '067_tuong-den-pho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex FOODS'},
#  {'filename': '067_tuong-den-pho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Tương Đen Phở'},
#  {'filename': '067_tuong-den-pho_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '230 g'},
#  {'filename': '067_tuong-den-pho_F_crop_3.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex'},
#  {'filename': '068_tuong-den-pho_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex FOODS'},
#  {'filename': '068_tuong-den-pho_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Tương Đen Phở'},
#  {'filename': '068_tuong-den-pho_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '19 09 24'},
#  {'filename': '068_tuong-den-pho_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '19 09 25'},
#  {'filename': '068_tuong-den-pho_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '230 g'},
#  {'filename': '068_tuong-den-pho_B_crop_5.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex'},
#  {'filename': '069_tuong-ot-chua-ngot_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '29/11/2'},
#  {'filename': '069_tuong-ot-chua-ngot_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '29/11/25'},
#  {'filename': '069_tuong-ot-chua-ngot_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex FOODS'},
#  {'filename': '069_tuong-ot-chua-ngot_F_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'TƯƠNG ỚT CHUA NGỌT'},
#  {'filename': '070_tuong-ot-chua-ngot_F_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '270 g'},
#  {'filename': '071_tuong-ot-chin-su_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Tương ớt'},
#  {'filename': '071_tuong-ot-chin-su_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'CHIN-SU'},
#  {'filename': '071_tuong-ot-chin-su_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '500 g'},
#  {'filename': '072_tuong-ot-chin-su_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '201124'},
#  {'filename': '072_tuong-ot-chin-su_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '200825'},
#  {'filename': '072_tuong-ot-chin-su_B_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'CHIN-SU'},
#  {'filename': '073_xot-uop-thit-nuong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Cholimex FOODS'},
#  {'filename': '073_xot-uop-thit-nuong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'XỐT ƯỚP THỊT NƯỚNG'},
#  {'filename': '073_xot-uop-thit-nuong_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '70 g'},
#  {'filename': '074_xot-uop-thit-nuong_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'XỐT ƯỚP THỊT NƯỚNG'},
#  {'filename': '074_xot-uop-thit-nuong_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '70 g'},
#  {'filename': '074_xot-uop-thit-nuong_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '12/12/24'},
#  {'filename': '074_xot-uop-thit-nuong_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '12/12/25'},
#  {'filename': '075_xot-ga-chien-nuoc-mam_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHIN-SU'},
#  {'filename': '075_xot-ga-chien-nuoc-mam_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '70 g'},
#  {'filename': '075_xot-ga-chien-nuoc-mam_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'GÀ CHIÊN NƯỚC MẮM'},
#  {'filename': '076_xot-ga-chien-nuoc-mam_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHIN-SU'},
#  {'filename': '076_xot-ga-chien-nuoc-mam_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '011224'},
#  {'filename': '076_xot-ga-chien-nuoc-mam_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '011225'},
#  {'filename': '076_xot-ga-chien-nuoc-mam_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '12 tháng kể từ ngày sản xuất'},
#  {'filename': '077_xot-ga-chien-nuoc-mam_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '077_xot-ga-chien-nuoc-mam_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': '- Xốt Gia Vị Hoàn Chỉnh - GÀ CHIÊN NƯỚC MẮM'},
#  {'filename': '078_xot-ga-chien-nuoc-mam_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Xốt Gia Vị Hoàn Chỉnh GÀ CHIÊN NƯỚC MẮM'},
#  {'filename': '078_xot-ga-chien-nuoc-mam_B_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '078_xot-ga-chien-nuoc-mam_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '17.10.24'},
#  {'filename': '078_xot-ga-chien-nuoc-mam_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '17.10.25'},
#  {'filename': '078_xot-ga-chien-nuoc-mam_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '80 g'},
#  {'filename': '079_duong-kinh-trang_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'đường kính trắng STANDARD WHITE SUGAR'},
#  {'filename': '079_duong-kinh-trang_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '500 g'},
#  {'filename': '080_duong-kinh-trang_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '05/06/2024'},
#  {'filename': '080_duong-kinh-trang_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '04/11/2024'},
#  {'filename': '080_duong-kinh-trang_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '18 tháng kể từ ngày đóng gói.'},
#  {'filename': '081_sot-spaghetti_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '15.09.2024'},
#  {'filename': '081_sot-spaghetti_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Sốt spaghetti Arrabbiata-Vị cay'},
#  {'filename': '081_sot-spaghetti_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'ofood'},
#  {'filename': '081_sot-spaghetti_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '120 g'},
#  {'filename': '082_hu-tieu-bo-kho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Nhịp Sống'},
#  {'filename': '082_hu-tieu-bo-kho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Hủ Tiếu Bò Kho'},
#  {'filename': '083_hu-tieu-bo-kho_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '05 12 24'},
#  {'filename': '083_hu-tieu-bo-kho_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '05 08 25'},
#  {'filename': '084_chao-thit-bam_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'VIFON'},
#  {'filename': '084_chao-thit-bam_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Cháo Thịt Bằm'},
#  {'filename': '084_chao-thit-bam_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '70'},
#  {'filename': '085_bot-suong-sao-den_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT SƯƠNG SÁO ĐEN'},
#  {'filename': '085_bot-suong-sao-den_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Vinathạch'},
#  {'filename': '085_bot-suong-sao-den_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '26/08/24'},
#  {'filename': '085_bot-suong-sao-den_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '25/02/26'},
#  {'filename': '085_bot-suong-sao-den_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '50 g'},
#  {'filename': '086_snack-tom-vi-muoi-ot-xanh_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Oishi'},
#  {'filename': '086_snack-tom-vi-muoi-ot-xanh_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Snack Tôm Vị Muối Ớt Xanh'},
#  {'filename': '087_tao-ninh-thuan_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'TAO NINH THUAN'},
#  {'filename': '087_tao-ninh-thuan_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '0.792 kg'},
#  {'filename': '087_tao-ninh-thuan_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '6.1.2025'},
#  {'filename': '088_tao-gala-mini-phap_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'TAO GALA MINI PHAP'},
#  {'filename': '088_tao-gala-mini-phap_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '0.476kg'},
#  {'filename': '088_tao-gala-mini-phap_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '1.1.2025'},
#  {'filename': '089_sapoche_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'SAPOCHE'},
#  {'filename': '089_sapoche_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '06-01-2025'},
#  {'filename': '089_sapoche_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '05 NGÀY KỂ TỪ NGÀY SẢN XUẤT'},
#  {'filename': '089_sapoche_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '500g'},
#  {'filename': '090_man-an-phuoc_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'MAN AN PHUOC'},
#  {'filename': '090_man-an-phuoc_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '0.554 kg'},
#  {'filename': '090_man-an-phuoc_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '7.1.2025'},
#  {'filename': '091_oi-nu-hoang_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'OI NU HOANG'},
#  {'filename': '091_oi-nu-hoang_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '1,188 kg'},
#  {'filename': '091_oi-nu-hoang_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '7.1.2025'},
#  {'filename': '092_trung-ga-tuoi_F_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '550g'},
#  {'filename': '092_trung-ga-tuoi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'TRỨNG GÀ TƯƠI'},
#  {'filename': '092_trung-ga-tuoi_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '29/12/2024'},
#  {'filename': '092_trung-ga-tuoi_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '11/01/2025'},
#  {'filename': '093_trung-ga-tuoi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'HAPPY EGG'},
#  {'filename': '093_trung-ga-tuoi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'TRỨNG GÀ TƯƠI'},
#  {'filename': '093_trung-ga-tuoi_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '02-01-2025'},
#  {'filename': '093_trung-ga-tuoi_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '366g'},
#  {'filename': '094_trung-ga-tuoi_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'HAPPY EGG'},
#  {'filename': '094_trung-ga-tuoi_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'TRỨNG GÀ TƯƠI'},
#  {'filename': '094_trung-ga-tuoi_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '366g'},
#  {'filename': '094_trung-ga-tuoi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '02-01-2025'},
#  {'filename': '095_trung-vit-muoi_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Trứng vịt Muối'},
#  {'filename': '095_trung-vit-muoi_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'PHƯƠNG NAM FARM'},
#  {'filename': '095_trung-vit-muoi_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '25 -12- 2024'},
#  {'filename': '095_trung-vit-muoi_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '240g'},
#  {'filename': '095_trung-vit-muoi_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '30 ngày (kể từ ngày đóng gói)'},
#  {'filename': '096_trung-vit-bac-thao_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'PHƯƠNG NAM FARM'},
#  {'filename': '096_trung-vit-bac-thao_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Trứng vịt BẮC THẢO'},
#  {'filename': '096_trung-vit-bac-thao_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '30 ngày (kể từ ngày đóng gói)'},
#  {'filename': '096_trung-vit-bac-thao_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '240g'},
#  {'filename': '096_trung-vit-bac-thao_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '21-12-2024'},
#  {'filename': '097_trung-cut_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'TRỨNG CÚT NGUYỄN HỒ'},
#  {'filename': '097_trung-cut_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'PHƯƠNG NAM FARM'},
#  {'filename': '097_trung-cut_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '27-12-2024'},
#  {'filename': '097_trung-cut_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '300g'},
#  {'filename': '097_trung-cut_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '15 ngày'},
#  {'filename': '098_trung-vit-tuoi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'PHƯƠNG NAM FARM'},
#  {'filename': '098_trung-vit-tuoi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Trứng vịt Tươi'},
#  {'filename': '098_trung-vit-tuoi_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '360g'},
#  {'filename': '099_trung-vit-tuoi_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Trứng Vịt Tươi'},
#  {'filename': '099_trung-vit-tuoi_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '360g'},
#  {'filename': '099_trung-vit-tuoi_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '12 ngày (kể từ ngày đóng gói)'},
#  {'filename': '099_trung-vit-tuoi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '28-12-2024'},
#  {'filename': '100_tao-do-khong-hat_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'TÁO ĐỎ KHÔNG HẠT'},
#  {'filename': '100_tao-do-khong-hat_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'VIETFRESH'},
#  {'filename': '100_tao-do-khong-hat_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '100G'},
#  {'filename': '101_tao-do-khong-hat_T_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '26 11 24'},
#  {'filename': '101_tao-do-khong-hat_T_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '25 11 25'},
#  {'filename': '102_dau-phong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'VIET THIEN'},
#  {'filename': '102_dau-phong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'ĐẬU PHỘNG'},
#  {'filename': '102_dau-phong_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '150 gram'},
#  {'filename': '102_dau-phong_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '20 11 24'},
#  {'filename': '102_dau-phong_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '20 11 25'},
#  {'filename': '103_pho-tai_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'PHỔ TAI'},
#  {'filename': '103_pho-tai_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'VIETFRESH'},
#  {'filename': '103_pho-tai_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '24-11-2024'},
#  {'filename': '103_pho-tai_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '50G'},
#  {'filename': '104_hanh-phi_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'HÀNH PHI'},
#  {'filename': '104_hanh-phi_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '50 g'},
#  {'filename': '105_hanh-phi_T_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '061221'},
#  {'filename': '105_hanh-phi_T_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '061225'},
#  {'filename': '106_dau-xanh-hat_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'VIET THIEN'},
#  {'filename': '106_dau-xanh-hat_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'ĐẬU XANH HẠT'},
#  {'filename': '106_dau-xanh-hat_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '150 gram'},
#  {'filename': '107_nam-dong-co_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'NẤM ĐÔNG CÔ'},
#  {'filename': '107_nam-dong-co_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'VIETFRESH'},
#  {'filename': '107_nam-dong-co_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '50G'},
#  {'filename': '108_hat-sen_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ĐỨC DŨNG'},
#  {'filename': '108_hat-sen_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'HẠT SEN'},
#  {'filename': '108_hat-sen_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '100g'},
#  {'filename': '109_hat-sen_T_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '29/10/24'},
#  {'filename': '109_hat-sen_T_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '28/10/25'},
#  {'filename': '110_me-trang_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ĐỨC DŨNG'},
#  {'filename': '110_me-trang_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'MÈ TRẮNG'},
#  {'filename': '110_me-trang_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '26 09 24'},
#  {'filename': '110_me-trang_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '25 09 25'},
#  {'filename': '111_dau-xanh-khong-vo_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'ĐẬU XANH KHÔNG VỎ'},
#  {'filename': '111_dau-xanh-khong-vo_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'TUẤN LINH'},
#  {'filename': '111_dau-xanh-khong-vo_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '01/12/2024'},
#  {'filename': '111_dau-xanh-khong-vo_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '01/12/2025'},
#  {'filename': '111_dau-xanh-khong-vo_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '150 g'},
#  {'filename': '112_dau-den_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'VIETFRESH'},
#  {'filename': '112_dau-den_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Đậu Đen'},
#  {'filename': '112_dau-den_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '150g'},
#  {'filename': '113_dau-do_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ĐỨC DŨNG'},
#  {'filename': '113_dau-do_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'ĐẬU ĐỎ'},
#  {'filename': '113_dau-do_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '150g'},
#  {'filename': '114_toi-phi_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '02 12 24'},
#  {'filename': '114_toi-phi_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '02 12 25'},
#  {'filename': '114_toi-phi_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'TỎI PHI'},
#  {'filename': '114_toi-phi_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '50 g'},
#  {'filename': '115_kho-heo-say-toi_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Khô heo sấy tỏi'},
#  {'filename': '115_kho-heo-say-toi_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '300 g'},
#  {'filename': '115_kho-heo-say-toi_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'C&B'},
#  {'filename': '116_kho-heo-say-toi_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Khô heo sấy tỏi'},
#  {'filename': '116_kho-heo-say-toi_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '05 12 2024'},
#  {'filename': '116_kho-heo-say-toi_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '05 12 2025'},
#  {'filename': '116_kho-heo-say-toi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '06 12 2024'},
#  {'filename': '117_dau-nanh-say-gion_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Đậu Nành Sấy Giòn'},
#  {'filename': '117_dau-nanh-say-gion_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '117_dau-nanh-say-gion_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'tili'},
#  {'filename': '118_dau-nanh-say-gion_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Đậu Nành Sấy Giòn'},
#  {'filename': '118_dau-nanh-say-gion_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '25/11/2024'},
#  {'filename': '118_dau-nanh-say-gion_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '25/11/2025'},
#  {'filename': '118_dau-nanh-say-gion_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '12 tháng kể từ NSX.'},
#  {'filename': '118_dau-nanh-say-gion_B_crop_4.jpg',
#   'label': 'brand',
#   'description_gt': 'tili'},
#  {'filename': '119_xoai-say-deo_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Xoài Sấy Dẻo'},
#  {'filename': '119_xoai-say-deo_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '18/11/2024'},
#  {'filename': '119_xoai-say-deo_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '18/11/2025'},
#  {'filename': '119_xoai-say-deo_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '119_xoai-say-deo_F_crop_4.jpg',
#   'label': 'brand',
#   'description_gt': 'tili'},
#  {'filename': '120_cha-bong-ga_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'chà bông Gà'},
#  {'filename': '120_cha-bong-ga_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '300 g'},
#  {'filename': '120_cha-bong-ga_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': 'C&B'},
#  {'filename': '121_cha-bong-ga_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Chà Bông Gà'},
#  {'filename': '121_cha-bong-ga_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '24 12 2024'},
#  {'filename': '121_cha-bong-ga_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '27 12 2024'},
#  {'filename': '121_cha-bong-ga_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '24 12 2025'},
#  {'filename': '122_nescafe-ca-phe-den-da_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'NESCAFÉ'},
#  {'filename': '122_nescafe-ca-phe-den-da_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'CÀ PHÊ ĐEN ĐÁ'},
#  {'filename': '123_nescafe-ca-phe-den-da_B_crop_0.jpg',
#   'label': 'weight',
#   'description_gt': '240 g'},
#  {'filename': '123_nescafe-ca-phe-den-da_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '23.06.2025'},
#  {'filename': '123_nescafe-ca-phe-den-da_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '9 tháng trước hạn sử dụng'},
#  {'filename': '124_hat-nem-aji-ngon_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'AJINOMOTO'},
#  {'filename': '124_hat-nem-aji-ngon_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Hạt nêm'},
#  {'filename': '124_hat-nem-aji-ngon_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '170g'},
#  {'filename': '125_hat-nem-aji-ngon_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Hạt nêm'},
#  {'filename': '125_hat-nem-aji-ngon_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '170 g'},
#  {'filename': '126_hat-nem-aji-ngon_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'AJINOMOTO'},
#  {'filename': '126_hat-nem-aji-ngon_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Hạt nêm'},
#  {'filename': '126_hat-nem-aji-ngon_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '127_xot-gia-vi-thit-nuong-ngu-vi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '127_xot-gia-vi-thit-nuong-ngu-vi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': '- Xốt Gia Vị Hoàn Chỉnh - THỊT NƯỚNG NGŨ VỊ'},
#  {'filename': '128_xot-gia-vi-thit-nuong-ngu-vi_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '128_xot-gia-vi-thit-nuong-ngu-vi_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Xốt Gia Vị Hoàn Chỉnh THỊT NƯỚNG NGŨ VỊ'},
#  {'filename': '128_xot-gia-vi-thit-nuong-ngu-vi_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '18.11.24'},
#  {'filename': '128_xot-gia-vi-thit-nuong-ngu-vi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '18.05.26'},
#  {'filename': '128_xot-gia-vi-thit-nuong-ngu-vi_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '80 g'},
#  {'filename': '129_xot-gia-vi-nuong-bbq_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '129_xot-gia-vi-nuong-bbq_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': '- Xốt Gia Vị Hoàn Chỉnh - NƯỚNG BBQ'},
#  {'filename': '130_xot-gia-vi-nuong-bbq_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '130_xot-gia-vi-nuong-bbq_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Xốt Gia Vị Hoàn Chỉnh NƯỚNG BBQ'},
#  {'filename': '130_xot-gia-vi-nuong-bbq_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '31.10.24'},
#  {'filename': '130_xot-gia-vi-nuong-bbq_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '30.01.26'},
#  {'filename': '130_xot-gia-vi-nuong-bbq_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '80 g'},
#  {'filename': '131_xot-gia-vi-canh-chua_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '131_xot-gia-vi-canh-chua_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': '- Xốt Gia Vị Hoàn Chỉnh - CANH CHUA'},
#  {'filename': '131_xot-gia-vi-canh-chua_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '80 g'},
#  {'filename': '132_xot-gia-vi-canh-chua_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Barona'},
#  {'filename': '132_xot-gia-vi-canh-chua_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Xốt Gia Vị Hoàn Chỉnh CANH CHUA'},
#  {'filename': '132_xot-gia-vi-canh-chua_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '23.11.24'},
#  {'filename': '132_xot-gia-vi-canh-chua_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '23.11.25'},
#  {'filename': '133_gia-vi-ca-kho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'AJINOMOTO'},
#  {'filename': '133_gia-vi-ca-kho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia vị nêm sẵn'},
#  {'filename': '133_gia-vi-ca-kho_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'Cá Kho'},
#  {'filename': '133_gia-vi-ca-kho_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '300g'},
#  {'filename': '134_gia-vi-canh-chua_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr'},
#  {'filename': '134_gia-vi-canh-chua_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia vị Hoàn Chính CANH CHUA'},
#  {'filename': '135_gia-vi-canh-chua_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '140624'},
#  {'filename': '135_gia-vi-canh-chua_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '140625'},
#  {'filename': '135_gia-vi-canh-chua_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '30 g'},
#  {'filename': '136_gia-vi-ca-kho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr SINCE 1838 '},
#  {'filename': '136_gia-vi-ca-kho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia vị Hoàn Chỉnh CÁ KHO'},
#  {'filename': '137_gia-vi-ca-kho_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '191124'},
#  {'filename': '137_gia-vi-ca-kho_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '190925'},
#  {'filename': '137_gia-vi-ca-kho_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '28g'},
#  {'filename': '138_gia-vi-thit-kho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Knorr SINCE 1838'},
#  {'filename': '138_gia-vi-thit-kho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia vị Hoàn Chỉnh THỊT KHO'},
#  {'filename': '139_gia-vi-thit-kho_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '221124'},
#  {'filename': '139_gia-vi-thit-kho_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '221125'},
#  {'filename': '139_gia-vi-thit-kho_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '28 g'},
#  {'filename': '140_cot-pho-bo_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ÔngChàVà'},
#  {'filename': '140_cot-pho-bo_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Cốt Phở Bò'},
#  {'filename': '140_cot-pho-bo_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '90 g'},
#  {'filename': '141_cot-pho-bo_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Cốt Phở Bò CHẤT LƯỢNG'},
#  {'filename': '141_cot-pho-bo_B_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Ông Chà Và'},
#  {'filename': '141_cot-pho-bo_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '03.12.24'},
#  {'filename': '141_cot-pho-bo_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '03.12.25'},
#  {'filename': '142_gia-vi-nem-lau-thai_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'AJINOMOTO'},
#  {'filename': '142_gia-vi-nem-lau-thai_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia vị nêm sẵn'},
#  {'filename': '142_gia-vi-nem-lau-thai_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'LẨU THÁI'},
#  {'filename': '143_gia-vi-bo-kho_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT GIA VỊ BÒ KHO'},
#  {'filename': '143_gia-vi-bo-kho_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '18G'},
#  {'filename': '144_gia-vi-bo-kho_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT GIA VỊ BÒ KHO'},
#  {'filename': '144_gia-vi-bo-kho_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '07.12.2024'},
#  {'filename': '144_gia-vi-bo-kho_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '07.12.2025'},
#  {'filename': '145_xot-uop-thit-nuong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'XỐT ƯỚP Thịt Nướng BARBECUE SAUCE'},
#  {'filename': '145_xot-uop-thit-nuong_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '70 g'},
#  {'filename': '145_xot-uop-thit-nuong_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'DellyCook'},
#  {'filename': '146_xot-uop-thit-nuong_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '16/10/24'},
#  {'filename': '146_xot-uop-thit-nuong_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '15 tháng kể từ ngày sản xuất.'},
#  {'filename': '147_bot-ngu-vi-huong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Bột NGŨ VỊ HƯƠNG'},
#  {'filename': '147_bot-ngu-vi-huong_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '20/11/2024'},
#  {'filename': '147_bot-ngu-vi-huong_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '20/11/2026'},
#  {'filename': '147_bot-ngu-vi-huong_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '5g'},
#  {'filename': '148_bot-ngu-vi-huong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT Ngũ vị hương'},
#  {'filename': '148_bot-ngu-vi-huong_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '10g'},
#  {'filename': '149_bot-ngu-vi-huong_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'NGŨ VỊ HƯƠNG'},
#  {'filename': '149_bot-ngu-vi-huong_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'Thành Lộc Foods'},
#  {'filename': '150_bot-ngu-vi-huong_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '101124'},
#  {'filename': '150_bot-ngu-vi-huong_B_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '20 g'},
#  {'filename': '150_bot-ngu-vi-huong_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '15g'},
#  {'filename': '151_bot-cary_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Vianco'},
#  {'filename': '151_bot-cary_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT CÀRY'},
#  {'filename': '151_bot-cary_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'CÀRY VIỆT ẤN'},
#  {'filename': '152_bot-cary_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BỘT CÀRY'},
#  {'filename': '152_bot-cary_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '15.10.2024'},
#  {'filename': '152_bot-cary_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '15.10.2026'},
#  {'filename': '152_bot-cary_B_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '10g'},
#  {'filename': '153_bot-cary_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Cà ri Tương Dâu'},
#  {'filename': '153_bot-cary_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '20 g'},
#  {'filename': '154_bot-cary_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Cà ri Tương Dậu'},
#  {'filename': '154_bot-cary_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '2 năm kể từ ngày sản xuất'},
#  {'filename': '154_bot-cary_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '20/06/2026'},
#  {'filename': '154_bot-cary_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '20/06/2024'},
#  {'filename': '155_bot-cary_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'CAU Bột Cari'},
#  {'filename': '155_bot-cary_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '10g'},
# ...
#   'description_gt': '19.12.2025'},
#  {'filename': '279_xot-spaghetti_B_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'Xốt Spaghetti Rose Thịt Cua'},
#  {'filename': '279_xot-spaghetti_B_crop_3.jpg',
#   'label': 'brand',
#   'description_gt': 'OTTOGI'},
#  {'filename': '280_banh-hoi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Sa Giang'},
#  {'filename': '280_banh-hoi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Hỏi'},
#  {'filename': '280_banh-hoi_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'Sa Giang'},
#  {'filename': '281_banh-hoi_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '23/08/24'},
#  {'filename': '281_banh-hoi_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '23/08/26'},
#  {'filename': '282_rong-nho-tach-nuoc_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHOICE L'},
#  {'filename': '282_rong-nho-tach-nuoc_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'RONG NHO TÁCH NƯỚC'},
#  {'filename': '282_rong-nho-tach-nuoc_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '100 g'},
#  {'filename': '283_rong-nho-tach-nuoc_D_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '17/10/2024'},
#  {'filename': '284_rong-bien-gion-tron-gia-vi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ofood'},
#  {'filename': '284_rong-bien-gion-tron-gia-vi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Rong biển giòn trộn gia vị'},
#  {'filename': '284_rong-bien-gion-tron-gia-vi_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '40 g'},
#  {'filename': '284_rong-bien-gion-tron-gia-vi_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '07.12.2024'},
#  {'filename': '284_rong-bien-gion-tron-gia-vi_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '06.12.2025'},
#  {'filename': '285_rong-bien-gion-tron-gia-vi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'ofood'},
#  {'filename': '285_rong-bien-gion-tron-gia-vi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Rong biển giòn trộn gia vị '},
#  {'filename': '285_rong-bien-gion-tron-gia-vi_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '40 g'},
#  {'filename': '285_rong-bien-gion-tron-gia-vi_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '07.12.2024'},
#  {'filename': '285_rong-bien-gion-tron-gia-vi_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '06.12.2025'},
#  {'filename': '286_banh-phong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Sa Giang'},
#  {'filename': '286_banh-phong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH PHỒNG ĐẶC SẢN'},
#  {'filename': '286_banh-phong_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'Sa Giang'},
#  {'filename': '286_banh-phong_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '287_banh-phong_D_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '01/11/24'},
#  {'filename': '287_banh-phong_D_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '01/11/26'},
#  {'filename': '288_banh-phong-tom_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHOICE L'},
#  {'filename': '288_banh-phong-tom_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH PHỒNG TÔM'},
#  {'filename': '288_banh-phong-tom_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '289_banh-phong-tom_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '13/12/24'},
#  {'filename': '289_banh-phong-tom_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '12/12/25'},
#  {'filename': '290_rong-bien_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Gimjaban'},
#  {'filename': '290_rong-bien_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '09/04/2024'},
#  {'filename': '290_rong-bien_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '08/04/2025'},
#  {'filename': '290_rong-bien_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '40 g'},
#  {'filename': '291_banh-phong-gao-lut_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'VinaBichchi'},
#  {'filename': '291_banh-phong-gao-lut_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'BÍCH-CHI'},
#  {'filename': '291_banh-phong-gao-lut_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH PHỒNG GẠO LỨT'},
#  {'filename': '291_banh-phong-gao-lut_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '292_banh-phong-gao-lut_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '10/05/24'},
#  {'filename': '292_banh-phong-gao-lut_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '09/05/25'},
#  {'filename': '293_banh-trang-gao_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Mikiri'},
#  {'filename': '293_banh-trang-gao_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH TRÁNG GẠO Cuốn Chả Ram'},
#  {'filename': '293_banh-trang-gao_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '31\\10\\2024'},
#  {'filename': '293_banh-trang-gao_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '02\\11\\2024'},
#  {'filename': '293_banh-trang-gao_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '31\\10\\2025'},
#  {'filename': '293_banh-trang-gao_F_crop_5.jpg',
#   'label': 'weight',
#   'description_gt': '100 g'},
#  {'filename': '293_banh-trang-gao_F_crop_6.jpg',
#   'label': 'date',
#   'description_gt': '12 tháng kể từ ngày sản xuất.'},
#  {'filename': '294_banh-trang-gao_B_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Mikiri'},
#  {'filename': '294_banh-trang-gao_B_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH TRÁNG GẠO Cuốn Chả Ram'},
#  {'filename': '294_banh-trang-gao_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '100 g'},
#  {'filename': '294_banh-trang-gao_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '31\\10\\2024'},
#  {'filename': '294_banh-trang-gao_B_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '02\\11\\2024'},
#  {'filename': '294_banh-trang-gao_B_crop_5.jpg',
#   'label': 'date',
#   'description_gt': '31\\10\\25'},
#  {'filename': '295_banh-da-me-vang-dua-soi_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHOICE L'},
#  {'filename': '295_banh-da-me-vang-dua-soi_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Đa Mè Vàng Dừa Sợi'},
#  {'filename': '295_banh-da-me-vang-dua-soi_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '400 g'},
#  {'filename': '296_banh-da-me-vang-dua-soi_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Đa Mè Vàng Dừa Sợi'},
#  {'filename': '296_banh-da-me-vang-dua-soi_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '29/11/2024'},
#  {'filename': '296_banh-da-me-vang-dua-soi_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '03/12/2024'},
#  {'filename': '296_banh-da-me-vang-dua-soi_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '29/11/2025'},
#  {'filename': '297_banh-trang_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH TRÁNG'},
#  {'filename': '297_banh-trang_F_crop_1.jpg',
#   'label': 'weight',
#   'description_gt': '400 g'},
#  {'filename': '297_banh-trang_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '09.11.2024'},
#  {'filename': '297_banh-trang_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '05.11.2025'},
#  {'filename': '297_banh-trang_F_crop_4.jpg',
#   'label': 'brand',
#   'description_gt': 'HƯƠNG NAM'},
#  {'filename': '298_banh-trang-khong-nhung-nuoc_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'CHOICE L'},
#  {'filename': '298_banh-trang-khong-nhung-nuoc_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Tráng Không Nhúng Nước'},
#  {'filename': '298_banh-trang-khong-nhung-nuoc_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '299_banh-trang-khong-nhung-nuoc_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh Tráng Không Nhúng Nước'},
#  {'filename': '299_banh-trang-khong-nhung-nuoc_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '21/12/2024'},
#  {'filename': '299_banh-trang-khong-nhung-nuoc_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '26/12/2024'},
#  {'filename': '299_banh-trang-khong-nhung-nuoc_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '21/12/2025'},
#  {'filename': '300_banh-trang-nuong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Mikiri'},
#  {'filename': '300_banh-trang-nuong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH TRÁNG NƯỚNG'},
#  {'filename': '301_banh-trang_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH TRÁNG'},
#  {'filename': '301_banh-trang_F_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'BÁNH TRÁNG Senta'},
#  {'filename': '301_banh-trang_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '300 gam'},
#  {'filename': '302_banh-trang_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '211124'},
#  {'filename': '302_banh-trang_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '211125'},
#  {'filename': '303_banh-phong-gao-lut_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'BÁNH PHỒNG GẠO LỨT'},
#  {'filename': '303_banh-phong-gao-lut_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '26/10/24'},
#  {'filename': '303_banh-phong-gao-lut_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '25/10/25'},
#  {'filename': '303_banh-phong-gao-lut_F_crop_3.jpg',
#   'label': 'weight',
#   'description_gt': '100 g'},
#  {'filename': '304_gia-vi-rac-com_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Enzy'},
#  {'filename': '304_gia-vi-rac-com_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Gia Vị Rắc Cơm'},
#  {'filename': '304_gia-vi-rac-com_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '30 g'},
#  {'filename': '305_gia-vi-rac-com_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '25/09/2024'},
#  {'filename': '305_gia-vi-rac-com_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '24/09/2025'},
#  {'filename': '305_gia-vi-rac-com_B_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '30 g'},
#  {'filename': '306_kho-bo-uc_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '29/03/2024'},
#  {'filename': '306_kho-bo-uc_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '29/08/2025'},
#  {'filename': '306_kho-bo-uc_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'KHÔ BÒ ÚC'},
#  {'filename': '306_kho-bo-uc_F_crop_3.jpg',
#   'label': 'brand',
#   'description_gt': 'TUYEN KY FOOD 1948'},
#  {'filename': '306_kho-bo-uc_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '30 g'},
#  {'filename': '307_thi-bo-kho_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'TUYEN KY FOOD 1948'},
#  {'filename': '307_thi-bo-kho_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Thịt Bò Khô'},
#  {'filename': '307_thi-bo-kho_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'TUYỀN KÝ'},
#  {'filename': '307_thi-bo-kho_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '20/09/2024'},
#  {'filename': '307_thi-bo-kho_F_crop_4.jpg',
#   'label': 'date',
#   'description_gt': '20/09/2025'},
#  {'filename': '307_thi-bo-kho_F_crop_5.jpg',
#   'label': 'weight',
#   'description_gt': '150g'},
#  {'filename': '308_muc-nuong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'hainamfoods'},
#  {'filename': '308_muc-nuong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'MỰC NƯỚNG CÁN DƯỚI TẨM ỚT'},
#  {'filename': '309_muc-nuong-can-duoi-tam-ot_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'MỰC NƯỚNG CÁN DƯỠI TẨM ỚT'},
#  {'filename': '309_muc-nuong-can-duoi-tam-ot_B_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': 'HAI NAM CO.,LTD'},
#  {'filename': '309_muc-nuong-can-duoi-tam-ot_B_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '19/11/2024'},
#  {'filename': '309_muc-nuong-can-duoi-tam-ot_B_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '19/11/2025'},
#  {'filename': '309_muc-nuong-can-duoi-tam-ot_B_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '60 g'},
#  {'filename': '310_bento_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '291124'},
#  {'filename': '310_bento_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '291125'},
#  {'filename': '311_bento_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Bento'},
#  {'filename': '312_thit-bo-kho_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '04/12/2024'},
#  {'filename': '312_thit-bo-kho_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '04/12/2025'},
#  {'filename': '312_thit-bo-kho_F_crop_2.jpg',
#   'label': 'name',
#   'description_gt': 'THỊT BÒ KHÔ'},
#  {'filename': '312_thit-bo-kho_F_crop_3.jpg',
#   'label': 'brand',
#   'description_gt': 'TUYẾN KÝ'},
#  {'filename': '312_thit-bo-kho_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '35g'},
#  {'filename': '313_thit-bo-kho_F_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '27/11/2024'},
#  {'filename': '313_thit-bo-kho_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '27/11/2025'},
#  {'filename': '313_thit-bo-kho_F_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'TUYEN KY FOOD 1948'},
#  {'filename': '313_thit-bo-kho_F_crop_3.jpg',
#   'label': 'name',
#   'description_gt': 'THỊT BÒ KHÔ CÀ RY'},
#  {'filename': '313_thit-bo-kho_F_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '60 g'},
#  {'filename': '314_nui-no_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'SG FOOD'},
#  {'filename': '314_nui-no_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Nui Nơ'},
#  {'filename': '314_nui-no_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '200 g'},
#  {'filename': '315_nui-no_F_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Nui Nơ'},
#  {'filename': '315_nui-no_F_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '09/04/24'},
#  {'filename': '315_nui-no_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '09/04/25'},
#  {'filename': '316_lap-xuong_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'wyn'},
#  {'filename': '316_lap-xuong_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'LẠP XƯỞNG VỊ GIA TRUYỀN'},
#  {'filename': '316_lap-xuong_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '500 g'},
#  {'filename': '317_lap-xuong_B_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '09/11/2024'},
#  {'filename': '317_lap-xuong_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '09/05/2025'},
#  {'filename': '318_dates-dried-fruit_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'BAKALLAND'},
#  {'filename': '318_dates-dried-fruit_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'DATES Dried Fruit'},
#  {'filename': '318_dates-dried-fruit_F_crop_2.jpg',
#   'label': 'weight',
#   'description_gt': '100g'},
#  {'filename': '319_dates-dried-fruit_T_crop_0.jpg',
#   'label': 'date',
#   'description_gt': '23.09.24'},
#  {'filename': '319_dates-dried-fruit_T_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '31.03.26'},
#  {'filename': '319_dates-dried-fruit_T_crop_2.jpg',
#   'label': 'brand',
#   'description_gt': 'BAKALLAND'},
#  {'filename': '320_banh-quy-lua-mi_D_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh quy lúa mì nguyên cám'},
#  {'filename': '320_banh-quy-lua-mi_D_crop_1.jpg',
#   'label': 'brand',
#   'description_gt': "McVitie's Digestive Minis"},
#  {'filename': '320_banh-quy-lua-mi_D_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '09/08/2024'},
#  {'filename': '320_banh-quy-lua-mi_D_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '09/02/2026'},
#  {'filename': '320_banh-quy-lua-mi_D_crop_4.jpg',
#   'label': 'weight',
#   'description_gt': '227,5 g'},
#  {'filename': '321_banh-yen-mach-sua_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Richy'},
#  {'filename': '321_banh-yen-mach-sua_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Bánh yến mạch sữa'},
#  {'filename': '321_banh-yen-mach-sua_F_crop_2.jpg',
#   'label': 'date',
#   'description_gt': '14 10 24'},
#  {'filename': '321_banh-yen-mach-sua_F_crop_3.jpg',
#   'label': 'date',
#   'description_gt': '13 04 26'},
#  {'filename': '322_snack-que-nhan-sua_F_crop_0.jpg',
#   'label': 'brand',
#   'description_gt': 'Oishi'},
#  {'filename': '322_snack-que-nhan-sua_F_crop_1.jpg',
#   'label': 'name',
#   'description_gt': 'Snack Que Nhân Sữa'},
#  {'filename': '323_socola-phu-dua_B_crop_0.jpg',
#   'label': 'name',
#   'description_gt': 'SÔ CÔ LA PHỦ DỪA'},
#  {'filename': '323_socola-phu-dua_B_crop_1.jpg',
#   'label': 'date',
#   'description_gt': '23/12/2024'},
#  ...]
